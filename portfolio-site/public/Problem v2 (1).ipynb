# %% [markdown]
# # Problem

# %% [markdown]
# ### Write a Pandas program to read the csv file **diamonds.csv** from a specified source and print the first 10 rows.<br>
# The csv file has the following columns.<br/><br/>
#
# | Column Name | Description |
# | :- | :- |
# | price	| price in US dollars (\$326--\$18,823) |
# | carat	| weight of the diamond (0.2--5.01) |
# | cut |quality of the cut (Fair, Good, Very Good, Premium, Ideal) |
# | color | diamond colour, from J (worst) to D (best) |
# | clarity | a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best)) |
# | x | length in mm (0--10.74) |
# | y	| width in mm (0--58.9) |
# | z	| depth in mm (0--31.8) |
# | depth	| total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79) |
# | table	| width of top of diamond relative to widest point (43--95) |

# %%
import pandas as pd

#pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)

diamonds = pd.read_csv('diamonds.csv')

print("First 10 rows:")
print(diamonds.head(10))
# Out:
# First 10 rows:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0  326.0  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0  326.0  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0  327.0  4.05  4.07  2.31
# 3   0.29    Premium     I     NaN   62.4   58.0  334.0  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0  335.0  4.34  4.35  2.75
# 5   0.24        NaN     J    VVS2   62.8   57.0  336.0  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0  336.0  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0  337.0  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0  337.0  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0  338.0  4.00  4.05  2.39

# %% [markdown]
# ### Write a Pandas program to find the number of rows and columns of the diamonds Dataframe.

# %%
rows = len(diamonds.index)
columns = len(diamonds.columns)
print("Num of rows:"+str(rows))
print("Num of columns:"+str(columns))
# Out:
# Num of rows:53940
# Num of columns:10

# %% [markdown]
# ### Write a Pandas program to find the data type of each column of the diamonds Dataframe.

# %%
diamonds.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price      float64
# x          float64
# y          float64
# z          float64
# dtype: object

# %% [markdown]
# ### Write a Pandas program to create a new 'quality-color' columns that concatenate the data from the 'cut' column with the data from the 'color' column.
# ### Eg, if 'cut' is 'Ideal' and 'color is 'E', 'quality-color' is 'Ideal E'

# %%
diamonds['quality-color'] = diamonds['cut'] + ' ' + diamonds['color']
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0  326.0  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0  326.0  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0  327.0  4.05  4.07  2.31
# 3   0.29  Premium     I     NaN   62.4   58.0  334.0  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0  335.0  4.34  4.35  2.75
#
#   quality-color
# 0       Ideal E
# 1     Premium E
# 2        Good E
# 3     Premium I
# 4        Good J

# %% [markdown]
# ### Now that we have the quality-color column, we do not need the cut column.
# ### Write a Pandas program to remove the 'cut' column of the diamonds Dataframe.

# %%
diamonds = diamonds.drop("cut",axis=1)
diamonds.head()
# Out:
#    carat color clarity  depth  table  price     x     y     z quality-color
# 0   0.23     E     SI2   61.5   55.0  326.0  3.95  3.98  2.43       Ideal E
# 1   0.21     E     SI1   59.8   61.0  326.0  3.89  3.84  2.31     Premium E
# 2   0.23     E     VS1   56.9   65.0  327.0  4.05  4.07  2.31        Good E
# 3   0.29     I     NaN   62.4   58.0  334.0  4.20  4.23  2.63     Premium I
# 4   0.31     J     SI2   63.3   58.0  335.0  4.34  4.35  2.75        Good J

# %% [markdown]
# ### Write a Pandas program to sort by 'color' in ascending order

# %%
diamonds.sort_values(['color'], ascending = True)
# Out:
#        carat color clarity  depth  table   price     x     y     z  \
# 53939   0.75     D     SI2   62.2   55.0  2757.0  5.83   NaN  3.64
# 7817    1.00     D     SI2   63.5   59.0  4295.0  6.35  6.32  4.02
# 7816    1.00     D     SI2   57.8   58.0  4295.0  6.61  6.55  3.80
# 7815    1.00     D     SI2   61.5   63.0  4295.0  6.32  6.27  3.87
# 7809    0.56     D      IF   61.9   57.0  4293.0  5.28  5.31  3.28
# ...      ...   ...     ...    ...    ...     ...   ...   ...   ...
# 4861    1.00     J     SI1   60.8   58.0  3712.0  6.39  6.44  3.90
# 18421   1.52     J     SI1   61.9   57.0  7491.0  7.37  7.33  4.55
# 18423   1.50     J     VS2   62.6   58.0  7492.0  7.25  7.29  4.55
# 42108   0.65     J     SI1   61.4   55.0  1276.0  5.58  5.62  3.44
# 14123   1.30     J     SI1   61.5   55.0  5728.0  7.03  7.06  4.33
#
#       quality-color
# 53939       Ideal D
# 7817    Very Good D
# 7816         Good D
# 7815    Very Good D
# 7809        Ideal D
# ...             ...
# 4861      Premium J
# 18421       Ideal J
# 18423   Very Good J
# 42108       Ideal J
# 14123       Ideal J
#
# [53940 rows x 10 columns]

# %% [markdown]
# ### Write the Pandas program to drop a row if any or all values in a row are missing. Print the DataFrame before and aftet dropping the missing rows and compare.

# %%
diamonds.head(50)


diamonds.dropna(axis=0, how='any', inplace=True)

diamonds.head(50)
# Out:
#     carat color clarity  depth  table  price     x     y     z quality-color
# 0    0.23     E     SI2   61.5   55.0  326.0  3.95  3.98  2.43       Ideal E
# 1    0.21     E     SI1   59.8   61.0  326.0  3.89  3.84  2.31     Premium E
# 2    0.23     E     VS1   56.9   65.0  327.0  4.05  4.07  2.31        Good E
# 4    0.31     J     SI2   63.3   58.0  335.0  4.34  4.35  2.75        Good J
# 6    0.24     I    VVS1   62.3   57.0  336.0  3.95  3.98  2.47   Very Good I
# 7    0.26     H     SI1   61.9   55.0  337.0  4.07  4.11  2.53   Very Good H
# 8    0.22     E     VS2   65.1   61.0  337.0  3.87  3.78  2.49        Fair E
# 9    0.23     H     VS1   59.4   61.0  338.0  4.00  4.05  2.39   Very Good H
# 10   0.30     J     SI1   64.0   55.0  339.0  4.25  4.28  2.73        Good J
# 11   0.23     J     VS1   62.8   56.0  340.0  3.93  3.90  2.46       Ideal J
# 12   0.22     F     SI1   60.4   61.0  342.0  3.88  3.84  2.33     Premium F
# 13   0.31     J     SI2   62.2   54.0  344.0  4.35  4.37  2.71       Ideal J
# 14   0.20     E     SI2   60.2   62.0  345.0  3.79  3.75  2.27     Premium E
# 15   0.32     E      I1   60.9   58.0  345.0  4.38  4.42  2.68     Premium E
# 16   0.30     I     SI2   62.0   54.0  348.0  4.31  4.34  2.68       Ideal I
# 17   0.30     J     SI1   63.4   54.0  351.0  4.23  4.29  2.70        Good J
# 18   0.30     J     SI1   63.8   56.0  351.0  4.23  4.26  2.71        Good J
# 19   0.30     J     SI1   62.7   59.0  351.0  4.21  4.27  2.66   Very Good J
# 20   0.30     I     SI2   63.3   56.0  351.0  4.26  4.30  2.71        Good I
# 21   0.23     E     VS2   63.8   55.0  352.0  3.85  3.92  2.48   Very Good E
# 22   0.23     H     VS1   61.0   57.0  353.0  3.94  3.96  2.41   Very Good H
# 23   0.31     J     SI1   59.4   62.0  353.0  4.39  4.43  2.62   Very Good J
# 24   0.31     J     SI1   58.1   62.0  353.0  4.44  4.47  2.59   Very Good J
# 25   0.23     G    VVS2   60.4   58.0  354.0  3.97  4.01  2.41   Very Good G
# 26   0.24     I     VS1   62.5   57.0  355.0  3.97  3.94  2.47     Premium I
# 27   0.30     J     VS2   62.2   57.0  357.0  4.28  4.30  2.67   Very Good J
# 28   0.23     D     VS2   60.5   61.0  357.0  3.96  3.97  2.40   Very Good D
# 29   0.23     F     VS1   60.9   57.0  357.0  3.96  3.99  2.42   Very Good F
# 30   0.23     F     VS1   60.0   57.0  402.0  4.00  4.03  2.41   Very Good F
# 31   0.23     F     VS1   59.8   57.0  402.0  4.04  4.06  2.42   Very Good F
# 32   0.23     E     VS1   60.7   59.0  402.0  3.97  4.01  2.42   Very Good E
# 33   0.23     E     VS1   59.5   58.0  402.0  4.01  4.06  2.40   Very Good E
# 34   0.23     D     VS1   61.9   58.0  402.0  3.92  3.96  2.44   Very Good D
# 35   0.23     F     VS1   58.2   59.0  402.0  4.06  4.08  2.37        Good F
# 36   0.23     E     VS1   64.1   59.0  402.0  3.83  3.85  2.46        Good E
# 37   0.31     H     SI1   64.0   54.0  402.0  4.29  4.31  2.75        Good H
# 38   0.26     D     VS2   60.8   59.0  403.0  4.13  4.16  2.52   Very Good D
# 39   0.33     I     SI2   61.8   55.0  403.0  4.49  4.51  2.78       Ideal I
# 40   0.33     I     SI2   61.2   56.0  403.0  4.49  4.50  2.75       Ideal I
# 41   0.33     J     SI1   61.1   56.0  403.0  4.49  4.55  2.76       Ideal J
# 42   0.26     D     VS2   65.2   56.0  403.0  3.99  4.02  2.61        Good D
# 43   0.26     D     VS1   58.4   63.0  403.0  4.19  4.24  2.46        Good D
# 44   0.32     H     SI2   63.1   56.0  403.0  4.34  4.37  2.75        Good H
# 45   0.29     F     SI1   62.4   58.0  403.0  4.24  4.26  2.65     Premium F
# 46   0.32     H     SI2   61.8   55.0  403.0  4.35  4.42  2.71   Very Good H
# 47   0.32     H     SI2   63.8   56.0  403.0  4.36  4.38  2.79        Good H
# 48   0.25     E     VS2   63.3   60.0  404.0  4.00  4.03  2.54   Very Good E
# 49   0.29     H     SI2   60.7   60.0  404.0  4.33  4.37  2.64   Very Good H
# 50   0.24     F     SI1   60.9   61.0  404.0  4.02  4.03  2.45   Very Good F
# 51   0.23     G     VS1   61.9   54.0  404.0  3.93  3.95  2.44       Ideal G

# %% [markdown]
# ### Write the Pandas program to show the data of the diamonds where length>5, width>5 and depth>5

# %%
diamonds[(diamonds['x'] > 5) & (diamonds['y'] > 5) & (diamonds['z'] > 5)]
# Out:
#        carat color clarity  depth  table    price     x      y      z  \
# 11778   1.83     J      I1   70.0   58.0   5083.0  7.34   7.28   5.12
# 13002   2.14     J      I1   69.4   57.0   5405.0  7.74   7.70   5.36
# 13118   2.15     J      I1   65.5   57.0   5430.0  8.01   7.95   5.23
# 13562   1.96     F      I1   66.6   60.0   5554.0  7.59   7.56   5.04
# 13757   2.22     J      I1   66.7   56.0   5607.0  8.04   8.02   5.36
# ...      ...   ...     ...    ...    ...      ...   ...    ...    ...
# 27748   2.00     G     SI1   63.5   56.0  18818.0  7.90   7.97   5.04
# 27749   2.29     I     VS2   60.8   60.0  18823.0  8.50   8.47   5.16
# 48410   0.51     E     VS1   61.8   54.7   1970.0  5.12   5.15  31.80
# 49189   0.51     E     VS1   61.8   55.0   2075.0  5.15  31.80   5.12
# 49905   0.50     G    VVS1   63.7   58.0   2180.0  5.01   5.04   5.06
#
#       quality-color
# 11778        Fair J
# 13002        Fair J
# 13118        Fair J
# 13562        Fair F
# 13757        Fair J
# ...             ...
# 27748   Very Good G
# 27749     Premium I
# 48410   Very Good E
# 49189       Ideal E
# 49905   Very Good G
#
# [1457 rows x 10 columns]
